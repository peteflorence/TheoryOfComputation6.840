# %% [markdown]
# # Lecture 2
# ## September 15, 2015
#
# ### Handout: Problem Set 1
#
# ### Last time:
# - Finite automata
# - Regular operations U, o, *
# - Regular expressions
#
# examples:
#
# $\Sigma^*$ = all strings
#
# $0^*$ = all strings of 0s
#
# $\emptyset$ = empty language
#
# $\epsilon$ = empty string
#
# Here's a regular expression:
#
# $(1 \cup \epsilon)0^*$
#
# This represents either a 1 followed by some number of 0s, or just 0s.
#
#
# ### Goal: show finite automata equivalent to regular expressions
# (In that they both give methods of describing the class of regular languages)
#
# Today:
# - regular languages closed under $\cup, o, *$
# - nondeterminism
# - conversion: regular expressions to finite automata
#
# #### Closure under $\cup$
#
# **Theorem**: If $A_1,A_2$ are regular languages, so is $A_1\cup A_2$
#
# **Proof**:
#
# Let $M_1 = (Q_1, \Sigma, \delta_1, q_1, F_1)$ recognize $A_1$
#
# $M_2 = (Q_2, \Sigma, \delta_2, q_2, F_2)$ recognize $A_2$
#
# Construct $M = (Q, \Sigma, \delta, q, F)$ recognize $A_1\cup A_2$
#
# $Q = Q_1 \times Q_2$
#
# $\delta((q,r),a) = (\delta_1(q,a),\delta_2(r,a))$
#
# $q_0 = (q_1, q_2)$
#
# NOT $F = F_1 \times F_2$ (Would require both to accept. This would give us closure under intersection.)
#
# Actually $F = (F_1 \times Q_2) \cup (Q_1 \times F_2)$

# %% [markdown]
# **Theorem**: If $A_1, A_2$ are regular, so is $A_1 \cdot A_2$
#
# **Proof**
#
# $M_1 = $
# $M_2 = $
#
# Constrcut $M = (Q, \Sigma, \delta, q_0, F)$ recognizes $A_1 \cdot A_2$
#
# Can we cut $w$ into two pieces, when taken together is $w$
#
# Put this on hold.
#
# ### Nodeterministic finite automata
#
# At every state, could be 0, 1, or many ways to go.
#
# If some finger is on an accpeting state at the end, we accept the input.
#
#
#
# **Theorem**: A is regular iff some NFA N recognizes A
#
# **Proof**
#
# Right direction is easy, since NFA includes DFA behavior.
#
# Left direction is harder. Do so by converting NFA N to DFA M.
